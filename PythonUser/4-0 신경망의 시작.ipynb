# %%
import tensorflow as tf

# %%
mnist = tf.keras.datasets.mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
 len(train_images)
# Out:
# 60000

# %%
train_labels
# Out:
# array([5, 0, 4, ..., 5, 6, 8], dtype=uint8)

# %%
models = tf.keras.models
layers = tf.keras.layers

network = models.Sequential()
network.add(layers.Dense(512, activation='relu', input_shape=(28*28,)))
network.add(layers.Dense(10, activation='softmax'))

# %%
network.compile(optimizer='rmsprop',
               loss='categorical_crossentropy',
               metrics=['accuracy'])

# %%
train_images = train_images.reshape((60000,28*28))
train_images = train_images.astype('float32') / 255

test_images = test_images.reshape((10000,28*28))
test_images = test_images.astype('float32') / 255

# %%
utils =  tf.keras.utils
train_labels = utils.to_categorical(train_labels)
test_labels = utils.to_categorical(test_labels)

# %%
network.fit(train_images, train_labels, epochs=5, batch_size=128)
# Out:
# Train on 60000 samples
# Epoch 1/5
# 60000/60000 [==============================] - 8s 137us/sample - loss: 0.2581 - accuracy: 0.9245
# Epoch 2/5
# 60000/60000 [==============================] - 7s 116us/sample - loss: 0.1057 - accuracy: 0.9686
# Epoch 3/5
# 60000/60000 [==============================] - 6s 102us/sample - loss: 0.0693 - accuracy: 0.9790
# Epoch 4/5
# 60000/60000 [==============================] - 6s 98us/sample - loss: 0.0513 - accuracy: 0.9845
# Epoch 5/5
# 60000/60000 [==============================] - 6s 97us/sample - loss: 0.0385 - accuracy: 0.9883

# %%
test_loss, test_acc = network.evaluate(test_images, test_labels)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...

# %%
print('test_acc:', test_acc)
# Out:
# test_acc: 0.9777
