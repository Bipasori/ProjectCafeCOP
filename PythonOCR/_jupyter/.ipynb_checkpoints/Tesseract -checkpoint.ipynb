# %% [markdown]
# # A comprehensive guide to OCR with Tesseract, OpenCV and Python
# https://nanonets.com/blog/ocr-with-tesseract/#technologyhowitworks
#
# 2021년 6월 by Filip Zelic & Anuj Sable
#
# 1. Preprocessing of the Image
# 2. Text Localization
# 3. Character Segmentation
# 4. Character Recognition
# 5. Post Processing
#
# ![image.png](attachment:image.png)
#
# Since 2006 it is developed by Google.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Technology - How it works
#
# Tesseract developed from OCRopus model in Python which was a fork of a LSMT in C++, called CLSTM. CLSTM is an implementation of the LSTM recurrent neural network model in C++, using the Eigen library for numerical computations.
#
# ![image.png](attachment:image.png)
#
# ### How Tesseract uses LSTM model
#
# ![image-2.png](attachment:image-2.png)

# %%
# pip install pytesseract

# %%
import cv2 
import pytesseract

# %%
img = cv2.imread('image.png')

# %%
img
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
# Adding custom options
custom_config = r'--oem 3 --psm 6'
pytesseract.image_to_string(img, config=custom_config)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\py3-image-resize\lib\site-packages\pytesseract\pytesseract.py in run_tesseract(input_filename, output_filename_base, extension, lang, config, nice, timeout)
#     251     try:
# --> 252         proc = subprocess.Popen(cmd_args, **subprocess_args())
#     253     except OSError as e:
#
# C:\Python37\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     774                                 errread, errwrite,
# --> 775                                 restore_signals, start_new_session)
#     776         except:
#
# ...
