# %% [markdown]
# # 파이썬 Python 코딩 - tesseract OCR 이미지에서 텍스트 추출
# https://www.youtube.com/watch?v=rNxMwtottmM
#
# 설치 :
# https://github.com/UB-Mannheim/tesseract/wiki
#
# 깃허브 :
# https://github.com/tesseract-ocr/
#
# 설치 후 data update :
# https://github.com/tesseract-ocr/tessdata

# %%
from PIL import Image
import pytesseract

# 실행파일 위치지정
pytesseract.pytesseract.tesseract_cmd = "C:/Program Files/Tesseract-OCR/tesseract.exe"

# %%
imgfile = Image.open("image.png")

# %%
imgfile
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=315x321 at 0x23D50DFC5C0>

# %%
text = pytesseract.image_to_string(imgfile)

# %%
print(text)
# Out:
# Welcome to Mel's
#
# 12/20/11
# 4:38 PM
#
#
#
#
# 2 Beef Burgr (€9,95/ea)
# SIDE: Fries
#
# 1 Bud Light 3.79
#
# 1 Bud
#
# Sub-total
# Sales Tax 2.50
# TOTAL 30.69

# %%
imgfile2 = Image.open("image2.png")

# %%
imgfile2
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=339x406 at 0x23D50DE1978>

# %%
text2 = pytesseract.image_to_string(imgfile2, lang='kor')

# %%
print(text2)
# Out:
# 현 금 영 수 증
#
#
#
#
#
# 가 맹 점 명 : 쁘 대 표 자 :
#
# 사 업 자 번 호 == 전 화 번 호 [ 기
#
# 주 소 : 서 룰 마 포구 상 암 동 마 ㅇ 미 만 모 피 스텔 1 단 지 1803
# 호
#
# 거 래 유 형 소 득 공 제
#
# 거 래 종 류 : 승 민 거래
#
# 식 별 번 호 : 11- 며 게게
#
# 취 소 시 원 거 래 일 자 :
#
# 거 래 일 시 2019/11/20 1098.30
#
# 공 급 가 액 : 17800 원
#
# 부 가 세 1.780 왼
#
# 봉 사 료 릴
#
# 합 계 19,580 원

# %%
print(text2)
# Out:
# 현 금 영 수 증
#
#
#
#
#
# 가 맹 점 명 : 쁘 대 표 자 :
#
# 사 업 자 번 호 == 전 화 번 호 [ 기
#
# 주 소 : 서 룰 마 포구 상 암 동 마 ㅇ 미 만 모 피 스텔 1 단 지 1803
# 호
#
# 거 래 유 형 소 득 공 제
#
# 거 래 종 류 : 승 민 거래
#
# 식 별 번 호 : 11- 며 게게
#
# 취 소 시 원 거 래 일 자 :
#
# 거 래 일 시 2019/11/20 1098.30
#
# 공 급 가 액 : 17800 원
#
# 부 가 세 1.780 왼
#
# 봉 사 료 릴
#
# 합 계 19,580 원

# %%
with open("result.txt", "w", encoding="utf8") as f:
    f.write(text2)
    f.write("\n\n\n")
    f.write(text2.replace(" ",""))
